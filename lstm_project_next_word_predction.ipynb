# %%
faqs = """
What is Dipanjan Pathak's primary area of interest?
Dipanjan Pathak is a Data Science Enthusiast, indicating his primary area of interest lies in data science, machine learning, deep learning, and related technologies.

What is Dipanjan Pathak's email address?
Dipanjan Pathak's email address is dipanjanpathak@gmail.com.

What is Dipanjan Pathak's LinkedIn profile link?
Dipanjan Pathak's LinkedIn profile can be accessed at linkedin.com/in/dipanjan-pathak.

What is Dipanjan Pathak's contact number?
Dipanjan Pathak's contact number is (+91) 9064518089.

What is Dipanjan Pathak's GitHub profile link?
Dipanjan Pathak's GitHub profile can be found at github.com/dipanjanpathak.

What is Dipanjan Pathak's personal website?
Dipanjan Pathak's personal website is www.dipanjan.tech.

What are Dipanjan Pathak's ongoing projects?
Dipanjan Pathak's ongoing projects include an ML, DL MERN E-Commerce project, which involves Machine Learning and Deep Learning. Another project is listed as "Updated soon," indicating more projects are in the pipeline.

What is the Mini GPT model project about?
The Mini GPT model project involves developing a GPT model based on transformer architecture for text generation tasks. Dipanjan implemented attention mechanisms and trained the model on the WikiText-2 dataset.

What is the Cold Email Generator project?
The Cold Email Generator project uses LangChain and the Groq API to extract job postings from career pages and generate tailored cold emails. This project showcases Dipanjan's skills in Generative AI.

What is the Stock Price Prediction Using LSTM project?
The Stock Price Prediction Using LSTM project involves building a stock price prediction model using Long Short-Term Memory (LSTM) networks. Dipanjan also deployed an interactive Django-based website for trend visualization.

What is the Real Estate Recommendation, Prediction, Analysis project?
This project is a MERN Stack App that uses Machine Learning (XGBoost) for prediction, cosine similarity for recommendation, and Plotly.js for live feature analysis on the web. The project can be viewed at www.property.dipanjan.tech.

What is the Movie Recommendation System project?
The Movie Recommendation System is a MERN Stack App that uses the TMDB dataset. Dipanjan performed data cleaning, feature engineering, and missing value imputation. The recommendation system is based on cosine similarity.

What is the Fine-Tuned Cat vs Dog Classifier project?
The Fine-Tuned Cat vs Dog Classifier project involves implementing transfer learning, adding CNN layers, and fine-tuning hyperparameters to enhance model performance and robustness.

What is Dipanjan Pathak's educational background?
Dipanjan Pathak holds a B.Tech in Mechanical Engineering from MAKAUT (July 2020 - June 2023) with a CGPA of 8.68. He also completed a Diploma in Mechanical Engineering from Barulpur Govt. Polytechnic (July 2016 - June 2019) with a CGPA of 7.72.

What certifications does Dipanjan Pathak hold?
Dipanjan Pathak holds the following certifications:

Data Science Mentorship Program (DSMP) from CampusX (Nov 2022 - August 2024).

Full Stack Data Science Pro (FSDS) from PW Skills (December 2023 - January 2025).

What are Dipanjan Pathak's skills in NLP?
Dipanjan Pathak has skills in NLP with nltk, which includes working with natural language processing tasks using the Natural Language Toolkit (nltk).

What are Dipanjan Pathak's skills in Computer Vision (CV)?
Dipanjan Pathak has skills in Computer Vision (CV), which involves working with image and video data, including tasks like object detection, image classification, and more.

What are Dipanjan Pathak's skills in GANs?
Dipanjan Pathak has skills in Generative Adversarial Networks (GANs), which are used for generating synthetic data, such as images, videos, or text.

What are Dipanjan Pathak's skills in Generative AI?
Dipanjan Pathak has skills in Generative AI, which involves creating models that can generate new content, such as text, images, or music, using techniques like GPT, BERT, and other generative models.

What is Dipanjan Pathak's experience with LangChain?
Dipanjan Pathak has experience with LangChain, a framework for developing applications powered by language models. He used it in his Cold Email Generator project to extract job postings and generate tailored emails.

What are Dipanjan Pathak's skills in Machine Learning (ML)?
Dipanjan Pathak has skills in Machine Learning (ML), which includes building predictive models, performing data analysis, and implementing algorithms like XGBoost, LSTM, and more.

What are Dipanjan Pathak's skills in Deep Learning (DL)?
Dipanjan Pathak has skills in Deep Learning (DL), which involves working with neural networks, including architectures like CNNs, LSTMs, and transformers.

What are Dipanjan Pathak's skills in Exploratory Data Analysis (EDA)?
Dipanjan Pathak has skills in Exploratory Data Analysis (EDA), which involves analyzing and visualizing data to understand patterns, trends, and relationships before building models.

What programming languages does Dipanjan Pathak know?
Dipanjan Pathak is proficient in Python, which is widely used in data science, machine learning, and web development.

What web frameworks does Dipanjan Pathak know?
Dipanjan Pathak knows Flask and Django, which are popular Python web frameworks used for building web applications.

What databases does Dipanjan Pathak know?
Dipanjan Pathak is familiar with SQL, MySQL, and PostgreSQL, which are relational database management systems used for storing and managing data.

What version control system does Dipanjan Pathak use?
Dipanjan Pathak uses Git, a distributed version control system for tracking changes in source code during software development.

What data visualization tools does Dipanjan Pathak know?
Dipanjan Pathak knows Matplotlib, Seaborn, and Plotly, which are Python libraries used for creating static, animated, and interactive visualizations.

What machine learning libraries does Dipanjan Pathak know?
Dipanjan Pathak is familiar with Scikit-Learn, TensorFlow, and PyTorch, which are popular libraries for building and training machine learning models.

What is Dipanjan Pathak's experience with OpenCV?
Dipanjan Pathak has experience with OpenCV, an open-source computer vision library used for image and video processing tasks.

What is Dipanjan Pathak's experience with Streamlit?
Dipanjan Pathak has experience with Streamlit, a Python library used for building interactive web applications for data science and machine learning projects.

What is Dipanjan Pathak's experience with NumPy?
Dipanjan Pathak has experience with NumPy, a Python library used for numerical computations, including working with arrays and matrices.

What is Dipanjan Pathak's experience with Pandas?
Dipanjan Pathak has experience with Pandas, a Python library used for data manipulation and analysis, particularly with tabular data.

What coursework has Dipanjan Pathak completed?
Dipanjan Pathak has completed coursework in:

Data Structures and Algorithms

Optimization for Machine Learning

Probability and Statistics

Machine Learning

Deep Learning

Natural Language Processing

Computer Vision

GANs

GPT & BERT

What is Dipanjan Pathak's experience with Data Structures and Algorithms?
Dipanjan Pathak has completed coursework in Data Structures and Algorithms, which involves understanding and implementing fundamental data structures like arrays, linked lists, trees, and algorithms like sorting and searching.

What is Dipanjan Pathak's experience with Optimization for Machine Learning?
Dipanjan Pathak has completed coursework in Optimization for Machine Learning, which involves learning techniques to optimize machine learning models, such as gradient descent, regularization, and hyperparameter tuning.

What is Dipanjan Pathak's experience with Probability and Statistics?
Dipanjan Pathak has completed coursework in Probability and Statistics, which involves understanding probability theory, statistical distributions, hypothesis testing, and statistical inference.

What is Dipanjan Pathak's experience with Machine Learning?
Dipanjan Pathak has completed coursework in Machine Learning, which involves learning supervised and unsupervised learning algorithms, model evaluation, and feature engineering.

What is Dipanjan Pathak's experience with Deep Learning?
Dipanjan Pathak has completed coursework in Deep Learning, which involves learning about neural networks, backpropagation, convolutional neural networks (CNNs), recurrent neural networks (RNNs), and transformers.

What is Dipanjan Pathak's experience with Natural Language Processing (NLP)?
Dipanjan Pathak has completed coursework in Natural Language Processing (NLP), which involves learning techniques for text processing, sentiment analysis, text generation, and working with models like GPT and BERT.

What is Dipanjan Pathak's experience with Computer Vision?
Dipanjan Pathak has completed coursework in Computer Vision, which involves learning techniques for image processing, object detection, image classification, and working with libraries like OpenCV.

What is Dipanjan Pathak's experience with GANs?
Dipanjan Pathak has completed coursework in GANs (Generative Adversarial Networks), which involves learning how to generate synthetic data using adversarial training techniques.

What is Dipanjan Pathak's experience with GPT & BERT?
Dipanjan Pathak has completed coursework in GPT & BERT, which involves learning about transformer-based models for natural language processing tasks like text generation, classification, and translation.

What is Dipanjan Pathak's experience with Flask?
Dipanjan Pathak has experience with Flask, a lightweight Python web framework used for building web applications and APIs.

What is Dipanjan Pathak's experience with Django?
Dipanjan Pathak has experience with Django, a high-level Python web framework used for building robust and scalable web applications.

What is Dipanjan Pathak's experience with SQL?
Dipanjan Pathak has experience with SQL, a programming language used for managing and querying relational databases.

What is Dipanjan Pathak's experience with MySQL?
Dipanjan Pathak has experience with MySQL, an open-source relational database management system used for storing and managing structured data.

What is Dipanjan Pathak's experience with PostgreSQL?
Dipanjan Pathak has experience with PostgreSQL, an advanced open-source relational database system known for its robustness and extensibility.

What is Dipanjan Pathak's experience with Git?
Dipanjan Pathak has experience with Git, a version control system used for tracking changes in code and collaborating with other developers.

What is Dipanjan Pathak's experience with Streamlit?
Dipanjan Pathak has experience with Streamlit, a Python library used for building interactive web applications for data science and machine learning projects.

What is Dipanjan Pathak's experience with OpenCV?
Dipanjan Pathak has experience with OpenCV, an open-source computer vision library used for image and video processing tasks.

What is Dipanjan Pathak's experience with TensorFlow?
Dipanjan Pathak has experience with TensorFlow, an open-source machine learning framework used for building and training deep learning models.

What is Dipanjan Pathak's experience with PyTorch?
Dipanjan Pathak has experience with PyTorch, an open-source machine learning library used for building and training deep learning models, particularly popular in research.

What is Dipanjan Pathak's experience with Scikit-Learn?
Dipanjan Pathak has experience with Scikit-Learn, a Python library used for implementing machine learning algorithms, including classification, regression, and clustering.

What is Dipanjan Pathak's experience with Matplotlib?
Dipanjan Pathak has experience with Matplotlib, a Python library used for creating static, animated, and interactive visualizations.

What is Dipanjan Pathak's experience with Seaborn?
Dipanjan Pathak has experience with Seaborn, a Python library built on top of Matplotlib for creating statistical graphics and visualizations.

What is Dipanjan Pathak's experience with Plotly?
Dipanjan Pathak has experience with Plotly, a Python library used for creating interactive and dynamic visualizations.

What is Dipanjan Pathak's experience with NumPy?
Dipanjan Pathak has experience with NumPy, a Python library used for numerical computations, including working with arrays and matrices.

What is Dipanjan Pathak's experience with Pandas?
Dipanjan Pathak has experience with Pandas, a Python library used for data manipulation and analysis, particularly with tabular data.

What is Dipanjan Pathak's experience with Data Science Mentorship Program (DSMP)?
Dipanjan Pathak is currently enrolled in the Data Science Mentorship Program (DSMP) offered by CampusX, which runs from November 2022 to August 2024. This program likely provides him with advanced training and mentorship in data science.

What is Dipanjan Pathak's experience with Full Stack Data Science Pro (FSDS)?
Dipanjan Pathak is enrolled in the Full Stack Data Science Pro (FSDS) program offered by PW Skills, which runs from December 2023 to January 2025. This program likely covers a wide range of data science topics, including machine learning, deep learning, and data engineering.

What is Dipanjan Pathak's experience with the WikiText-2 dataset?
Dipanjan Pathak used the WikiText-2 dataset to train his Mini GPT model. This dataset is commonly used for language modeling tasks and consists of a collection of Wikipedia articles.

What is Dipanjan Pathak's experience with the TMDB dataset?
Dipanjan Pathak used the TMDB dataset for his Movie Recommendation System project. This dataset contains information about movies, including titles, genres, ratings, and more, which he used to build a recommendation system.

What is Dipanjan Pathak's experience with XGBoost?
Dipanjan Pathak used XGBoost in his Real Estate Recommendation, Prediction, Analysis project. XGBoost is a powerful machine learning algorithm used for regression and classification tasks, known for its speed and performance.

What is Dipanjan Pathak's experience with Cosine Similarity?
Dipanjan Pathak used Cosine Similarity in both his Real Estate Recommendation and Movie Recommendation System projects. Cosine similarity is a metric used to measure the similarity between two vectors, often used in recommendation systems.

What is Dipanjan Pathak's experience with Plotly.js?
Dipanjan Pathak used Plotly.js in his Real Estate Recommendation, Prediction, Analysis project for live feature analysis on the web. Plotly.js is a JavaScript library used for creating interactive and dynamic visualizations.

What is Dipanjan Pathak's experience with Transfer Learning?
Dipanjan Pathak implemented Transfer Learning in his Fine-Tuned Cat vs Dog Classifier project. Transfer learning involves using a pre-trained model and fine-tuning it for a specific task, which helps improve model performance with less data.

What is Dipanjan Pathak's experience with CNN layers?
Dipanjan Pathak added CNN layers in his Fine-Tuned Cat vs Dog Classifier project. Convolutional Neural Network (CNN) layers are used in image processing tasks to extract features from images.

What is Dipanjan Pathak's experience with Hyperparameter Tuning?
Dipanjan Pathak fine-tuned hyperparameters in his Fine-Tuned Cat vs Dog Classifier project. Hyperparameter tuning involves adjusting the parameters of a model to optimize its performance.

What is Dipanjan Pathak's experience with the Groq API?
Dipanjan Pathak used the Groq API in his Cold Email Generator project to extract job postings and generate tailored cold emails. The Groq API is likely used for natural language processing tasks.

What is Dipanjan Pathak's experience with the MERN Stack?
Dipanjan Pathak has experience with the MERN Stack, which includes MongoDB, Express.js, React, and Node.js. He used this stack in his Real Estate Recommendation and Movie Recommendation System projects.

What is Dipanjan Pathak's experience with MongoDB?
Dipanjan Pathak likely has experience with MongoDB, a NoSQL database used in the MERN stack for storing and managing data in his projects.

What is Dipanjan Pathak's experience with Express.js?
Dipanjan Pathak likely has experience with Express.js, a web application framework for Node.js used in the MERN stack for building APIs and web applications.

What is Dipanjan Pathak's experience with React?
Dipanjan Pathak likely has experience with React, a JavaScript library used in the MERN stack for building user interfaces in his projects.

What is Dipanjan Pathak's experience with Node.js?
Dipanjan Pathak likely has experience with Node.js, a JavaScript runtime used in the MERN stack for building server-side applications.

What is Dipanjan Pathak's experience with Data Cleaning?
Dipanjan Pathak performed Data Cleaning in his Movie Recommendation System project. Data cleaning involves removing or correcting inaccurate, incomplete, or irrelevant data from a dataset.

What is Dipanjan Pathak's experience with Feature Engineering?
Dipanjan Pathak performed Feature Engineering in his Movie Recommendation System project. Feature engineering involves creating new features or modifying existing ones to improve model performance.

What is Dipanjan Pathak's experience with Missing Value Imputation?
Dipanjan Pathak performed Missing Value Imputation in his Movie Recommendation System project. Missing value imputation involves filling in missing data points using various techniques like mean, median, or predictive models.

What is Dipanjan Pathak's experience with Interactive Websites?
Dipanjan Pathak built an Interactive Django-based Website for his Stock Price Prediction Using LSTM project. Interactive websites allow users to visualize and interact with data in real-time.

What is Dipanjan Pathak's experience with Trend Visualization?
Dipanjan Pathak implemented Trend Visualization in his Stock Price Prediction Using LSTM project. Trend visualization involves using graphs and charts to display data trends over time.

What is Dipanjan Pathak's experience with Text Generation?
Dipanjan Pathak worked on Text Generation tasks in his Mini GPT model project. Text generation involves using models to generate coherent and contextually relevant text.

What is Dipanjan Pathak's experience with Attention Mechanisms?
Dipanjan Pathak implemented Attention Mechanisms in his Mini GPT model project. Attention mechanisms are used in neural networks to focus on specific parts of the input data, improving model performance.

What is Dipanjan Pathak's experience with Transformer Architecture?
Dipanjan Pathak developed a Mini GPT model based on Transformer Architecture. Transformer architecture is a type of neural network architecture used in natural language processing tasks like text generation and translation.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
# No of vocabulary
len(tokenizer.word_index)
# Out:
# 473

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[4, 3],
#  [4, 3, 1],
#  [4, 3, 1, 8],
#  [4, 3, 1, 8, 206],
#  [4, 3, 1, 8, 206, 207],
#  [4, 3, 1, 8, 206, 207, 40],
#  [4, 3, 1, 8, 206, 207, 40, 208],
#  [1, 6],
#  [1, 6, 3],
#  [1, 6, 3, 15],
#  [1, 6, 3, 15, 14],
#  [1, 6, 3, 15, 14, 32],
#  [1, 6, 3, 15, 14, 32, 290],
#  [1, 6, 3, 15, 14, 32, 290, 209],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40, 208],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40, 208, 291],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40, 208, 291, 9],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40, 208, 291, 9, 14],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40, 208, 291, 9, 14, 32],
#  [1, 6, 3, 15, 14, 32, 290, 209, 21, 206, 207, 40, 208, 291, 9, 14, 32, 20],
#  [1,
#   6,
#   3,
#   15,
#   14,
#   32,
#   290,
#   209,
#   21,
#   206,
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   4,   3],
#        [  0,   0,   0, ...,   4,   3,   1],
#        [  0,   0,   0, ...,   3,   1,   8],
#        ...,
#        [  0,   0,   0, ...,  45,  41,  62],
#        [  0,   0,   0, ...,  41,  62,   5],
#        [  0,   0,   0, ...,  62,   5, 274]], dtype=int32)

# %%
padded_input_sequences.shape
# Out:
# (2504, 44)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (2504, 43)

# %%
y.shape
# Out:
# (2504,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=474)

# %%
y.shape
# Out:
# (2504, 474)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# Build Model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=max_len - 1))
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index) + 1, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# Compile Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Explicitly build the model
model.build(input_shape=(None, max_len - 1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 43, 100)             │          47,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 43, 150)             │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 150)                 │         180,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 474)                 │          71,574 │
# ...

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.0298 - loss: 5.7557
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0602 - loss: 5.0973
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.1015 - loss: 4.8407
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.1353 - loss: 4.6314
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.1654 - loss: 4.4668
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2381 - loss: 4.1675
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2500 - loss: 3.9997
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2948 - loss: 3.7118
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3293 - loss: 3.4400
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3292 - loss: 3.3123
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3603 - loss: 3.0852
# ...

# %%
text =  'Dipanjan'
token_text = tokenizer.texts_to_sequences([text])
print("Word token: ",token_text)
# Out:
# Word token:  [[1]]

# %%
print("Word token: ",token_text[0]) # converting to 1D
token_text = tokenizer.texts_to_sequences([text])[0]
# Out:
# Word token:  [1]

# %%
padding_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
model.predict(padding_token_text).shape # it will give 283 probablity
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# (1, 474)

# %%
import time
import numpy as np
text = "Dipanjan Pathak introduction"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Dipanjan Pathak introduction has
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Dipanjan Pathak introduction has experience
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Dipanjan Pathak introduction has experience with
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Dipanjan Pathak introduction has experience with numpy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Dipanjan Pathak introduction has experience with numpy a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Dipanjan Pathak introduction has experience with numpy a python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Dipanjan Pathak introduction has experience with numpy a python library
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Dipanjan Pathak introduction has experience with numpy a python library used
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Dipanjan Pathak introduction has experience with numpy a python library used for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ...
